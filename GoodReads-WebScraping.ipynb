# %% [markdown]
# # Data 200: Data Systems for Data Analytics

# %% [markdown]
# # Name: Luke Finkielstein

# %% [markdown]
# # Take Home Final Exam
# <font color='red'>**Due Date:** Dec 20, 5p (T-F 1:30p section) </font> <br>
# <font color='red' style="margin-left: 1.85cm; display: inline-block;">Dec 21, 11:59a (T-F 3p section)</font>
#
# ---
#
# ### **Task**: Scrape data from Goodreads.com 📚
#
# ---
#
# ### **Objective**
# For this exam, you will scrape and analyze data from Goodreads.com. The work is split into two parts, each focusing on different aspects of the data
# 1. **"Best Books" Analysis**: Explore Goodreads' "Best Books" lists for a specific year.
# 2. **Author-Level Analysis**: Study the trends and patterns in the works of a specific author.
#
# ---
#
# ### **Instructions**
#
# #### **Task 1: Best Books**
# You are tasked with analyzing Goodreads' "Best Books" lists for a specific year based on the **first letter of your first name**. For example, if your first name starts with **A–E**, you are assigned to the year **2023**; if it starts with **F–J**, you are assigned to **2022**, and so on:
#
# | Initials | Assigned Year | URL                                              |
# |----------|---------------|---------------------------------------------------------|
# | A–E      | 2023          | [Best Books of 2023](https://www.goodreads.com/list/best_of_year/2023) |
# | F–J      | 2022          | [Best Books of 2022](https://www.goodreads.com/list/best_of_year/2022) |
# | K–O      | 2021          | [Best Books of 2021](https://www.goodreads.com/list/best_of_year/2021) |
# | P–T      | 2020          | [Best Books of 2020](https://www.goodreads.com/list/best_of_year/2020) |
# | U–Z      | 2019          | [Best Books of 2019](https://www.goodreads.com/list/best_of_year/2019) |
#
#
#
# **Your Tasks**:
# 1. Scrape data from the Goodreads "Best Books of [Year]" list:
#    - **URL**: https://www.goodreads.com/list/best_of_year/2023 (replace the year with your assigned year). You can also use the table above.
# 2. Collect the following data for each book:
#    - Title
#    - Publication date (first published)
#    - Author
#    - Genre (if available, and feel free to pick the first genre listed)
#    - Average rating
#    - Number of ratings
#    - Number of pages
#    - Rank
#    - Language (if available)
#    - Number of people who are currently reading (if available)
#    - Number of people who want to read (if available)
# 3. Perform the following analyses:
#    - **Genre ratings**:
#        - Compare average ratings across genres. Which 2-3 genres tends to have the highest ratings? Create a table showing average rating score, and average rank by genre.
#    - **Popularity and ratings**:
#        - Examine whether books with more ratings tend to have higher or lower average scores. Create a scatterplot showing the relationship between the number of ratings and average rating. On the x-axis, you should have **number of ratings**; on the y-axis, you should have **average rating**.
#
# ---
#
# #### **Task 2: Author-Level Analysis**
# You are now tasked with analyzing books by a specific author based on the **first letter of your first name**:
#
# | Your first name initial | Author              | Author Goodreads link                               | Birthday       |
# |----------|---------------------|--------------------------------------------------------------------|----------------|
# | A–E      | Stephen King        | [Stephen King](https://www.goodreads.com/author/list/3389)         | Sep 21, 1947   |
# | F–J      | George R.R. Martin  | [George R.R. Martin](https://www.goodreads.com/author/list/346732) | Sep 20, 1948   |
# | K–O      | Ernest Hemingway    | [Ernest Hemingway](https://www.goodreads.com/author/list/1455)     | Jul 21, 1899   |
# | P–T      | Neil Gaiman         | [Neil Gaiman](https://www.goodreads.com/author/list/1221698)       | Nov 10, 1960   |
# | U–Z      | Nora Roberts        | [Nora Roberts](https://www.goodreads.com/author/list/625)          | Oct 10, 1950   |
#
#
# **Your Tasks**:
# 1. Scrape all books by your assigned author:
#    - Use the link provided for your author.
# 2. Collect the following data for each book:
#    - Title
#    - Publication date (first published)
#    - Author
#    - Genre (if available, and feel free to pick the first genre listed)
#    - Average rating
#    - Number of ratings
#    - Number of pages
#    - Rank (from the books written by the author)
#    - Language (if available)
#    - Number of people who are currently reading (if available)
#    - Number of people who want to read (if available)
# 3. Perform the following analyses:
#    - **Language Distribution**:
#      - How many books has the author published in English? In other languages? Create a table showing the count of books by language.
#    - **Author's Age and Page Count**:
#      - Do authors tend to write longer books as they age? Use the author's birthday to calculate their age at the time of each book's publication. Create a line plot with **author's age** on the x-axis and **page count** on the y-axis.
#    - **Author's Age and Rating**:
#      - For English-only books, create a line plot with **author's age** on the x-axis and **average rating** on the y-axis.
#      - Repeat the analysis including books in languages other than English. Does your interpretation change?
#    - **Pages vs. Ratings**:
#      - Is there a relationship between the number of pages and a book's average rating? Create a scatterplot with **page count** on the x-axis and **average rating** on the y-axis.
#    - **Interest on a book**:
#      - Is there a relationship between the number of people who are currently reading the book and the number of people who left a rating? Create a scatterplot with **number of people who are currently reading** on the x-axis and **number of ratings** on the y-axis. Create a second scatterplot with **average rating** on the y-axis. Do books with more interest tend to receive higher ratings?
#
# ---
#
# ### **Submission Requirements**
# Submit your work as a single `.ipynb` file, along with a copy of it as a `.md` file. The notebook should include:
# 1. **Code**:
#    - Well-documented python code using Selenium for web scraping.
#    - Proper error handling and strategies for dynamic content.
# 2. **Cleaned Data**:
#    - Include the cleaned datasets from both tasks as .csv files. You can upload them in your github repo.
# 3. **Analysis and Report**:
#    - Present your findings using markdown cells, tables, and visualizations you make in python.
#    - Address all questions posed for your assigned tasks.
# 4. **Visualizations**:
#    - Include relevant charts (e.g., bar charts, line plots, scatterplots) to support your conclusions.
#
# ---
#
# ### **Rubric**
#
# | Item                        | Weight |
# |-----------------------------|--------|
# | Code accuracy               | 25%    |
# | Code clarity and annotation | 25%    |
# | Exploratory data analysis   | 25%    |
# | Discussion of findings      | 25%    |
#
# ---
#
# ### **Tips**
# - Make sure to insert time.sleep() right after you request driver to go to a link (before requesting elements). Make sure to wait at least 0.7 second, or even slightly higher if you run into issues.
# - Try-except blocks will be your friend because xpath positions on a page may differ depending on the book and content availability.
#
# ---
#
# ### **Resources**
# - Course notes on Github
# - Selenium documentation: https://www.selenium.dev/documentation/
# - Pandas documentation: https://pandas.pydata.org/docs/
# - Matplotlib documentation: https://matplotlib.org/stable/contents.html
#
# Good luck! 🏁

# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import random

# Title
# Publication date (first published)
# Author
# Genre (if available, and feel free to pick the first genre listed)
# Average rating
# Number of ratings
# Number of pages
# Rank
# Language (if available)
# Number of people who are currently reading (if available)
# Number of people who want to read (if available)

driver = webdriver.Chrome()

driver.get('https://www.goodreads.com/list/best_of_year/2021?id=157516.Best_Books_of_2021')

title = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[1]/div[1]/h1').text
title

pub_date = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/span[1]/span/div/p[2]').text[16:]
pub_date

author = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[1]/h3/div/span[1]/a/span[1]').text
author

genre = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/ul/span[1]/span[2]/a/span').text
genre

avg_rating = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[2]/a/div[1]/div').text
avg_rating

num_ratings = int(driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[2]/a/div[2]/div/span[1]').text.replace('ratings', '').replace(',', '').strip())
num_ratings

pages = int(driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/span[1]/span/div/p[1]').text.replace(', Hardcover', '').replace(' pages', ''))
pages

rank = int(driver.find_element('xpath', '//*[@id="all_votes"]/table/tbody/tr[1]/td[1]').text)
rank

language = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/span[2]/div[1]/span/div/dl/div[5]/dd/div/div[1]').text
language



num_reading = convert_abbrev_num(driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[8]/div/div[1]/span/div[2]/div').text.replace(' people are currently reading', ''))
num_reading

num_want_read = convert_abbrev_num(driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[8]/div/div[2]/span/div[2]/div').text.replace(' people want to read', ''))
num_want_read

# %%
## xpath for first and second books

# title from main page
//*[@id="all_votes"]/table/tbody/tr[1]/td[3]/a/span
//*[@id="all_votes"]/table/tbody/tr[2]/td[3]/a/span

# inner book title 
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[1]/div[1]/h1
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[1]/div[1]/h1


# pub date 
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/span[1]/span/div/p[2]
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/span[1]/span/div/p[2]

# Genre (if available, and feel free to pick the first genre listed)
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/ul/span[1]/span[2]/a/span
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/ul/span[1]/span[2]/a/span

# Average rating
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[2]/a/div[1]/div
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[2]/a/div[1]/div

# Number of ratings
//*[@id="ReviewsSection"]/div[5]/div[1]/div[1]/div/div[2]/div/span[1]/text()[1]
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[2]/a/div[2]/div/span[1]/text()[1]

# Number of pages
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/span[1]/span/div/p[1]
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/span[1]/span/div/p[1]

# Rank
//*[@id="all_votes"]/table/tbody/tr[1]/td[1]
//*[@id="all_votes"]/table/tbody/tr[2]/td[1]

# Language (if available)
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/span[2]/div[1]/span/div/dl/div[5]/dd/div/div[1]
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/span[2]/div[1]/span/div/dl/div[4]/dd/div/div[1]

# Number of people who are currently reading (if available)
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[8]/div/div[1]/span/div[2]/div
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[8]/div/div[1]/span/div[2]/div

# Number of people who want to read (if available)
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[8]/div/div[2]/span/div[2]/div
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[8]/div/div[2]/span/div[2]/div

# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import random
import time 

import pandas as pd
import numpy as np
from selenium import webdriver
import random
import time

def scrape_book(i):
    """Scrape all info from a singular book."""
    
    try:
        # Click into the book
        rank = i
        
        # Access the book link on the main page
        book_button = driver.find_element('xpath', f'//*[@id="all_votes"]/table/tbody/tr[{i}]/td[3]/a/span')
        book_button.click()
       
        # Check for pop-up ad
        time.sleep(random.uniform(1.9, 2.4))
        try:
            ad_button = driver.find_element('xpath', '/html/body/div[3]/div/div[1]/div/div/button')
            ad_button.click()
            time.sleep(random.uniform(1.9, 2.4))
    
        except:
            print('no ad') 
       
        # Scrape info
        book_info = []
        title = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[1]/div[1]/h1').text
        
        # Extract publication date
        try:
            try:
                pub_date = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/div/span[1]/span/div/p[2]').text
            except:
                pub_date = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/div/span[1]/span/div/p').text
        except:
            pub_date = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/span[1]/span/div/p[2]').text
        # Extract other book details
        author = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[1]/h3/div/span[1]/a/span[1]').text
        avg_rating = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[2]/a/div[1]/div').text
        num_ratings = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[2]/a/div[2]/div/span[1]').text
        try:
           pages = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/div/span[1]/span/div/p[1]').text
        except:
            pages = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/span[1]/span/div/p[1]').text
        
        # Optional fields
        try:
            genre = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[5]/ul/span[1]/span[2]/a/span').text
        except:
            genre = None
    
        try:
            num_reading = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/div[1]/span/div[2]/div').text
        except:
            num_reading = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[8]/div/div[1]/span/div[2]/div').text
        try:
            num_want_read = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/div[2]/span/div[2]/div').text
        except:
            num_want_read = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[8]/div/div[2]/span/div[2]/div').text
        # Language (if available)
        try:
            language = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/div/span[2]/div[1]/span/div/dl/div[5]/dd/div/div[1]').text
        except:
            language = None
    
        # Back to book list page
        time.sleep(random.uniform(0.7,1.2))
        driver.back()
        
        if pub_date:  # return book info if publication date is available
            book_info.append([title, pub_date, author, genre, avg_rating, num_ratings, pages, rank, language, num_reading, num_want_read])
        return book_info
    
    except:
        driver.back()  # Ensure the browser navigates back even if an error occurs
        return None  # Return None or an empty list to indicate failure





def scrape_page(books_per_page):
    """Scrape a page of books."""
    books = []
    for i in range(1, books_per_page + 1):
        print(f"Scraping book {i}")
        book = scrape_book(i)
        if book:  # Only add to the list if the book scrape was successful
            books.extend(book)
        else:
            print(f"Book {i} failed")
    return books


def scrape_all_pages(url, pages, books_per_page):
    """Scrape all pages of books."""
    books = []
    for i in range(1, pages + 1):
        page_url = f"{url}{i}"
        driver.get(page_url)
        print(f'Scraping page {i}')
        books.extend(scrape_page(books_per_page))
        time.sleep(random.uniform(1.9, 2.4))

    # Save to CSV
    books_df = pd.DataFrame(books, columns=['Title', 'Publication Date', 'Author', 'Genre', 'Average Rating', 'Number of Ratings', 
                                            'Pages', 'Rank','Language', 'Currently Reading', 'Want to Read'])
    books_df.to_csv('task1.csv')
    return books_df

# %%
driver = webdriver.Chrome()
driver.get('https://www.goodreads.com/list/best_of_year/2021?id=157516.Best_Books_of_2021&page=2')
scrape_page(5)
# Out:
# Scraping book 1
# no ad
# Scraping book 2
# Scraping book 3
# no ad
# Scraping book 4
# no ad
# Scraping book 5
# no ad
# [['Harlem Shuffle',
#   'First published September 14, 2021',
#   'Colson Whitehead',
#   None,
#   '3.73',
#   '74,660 ratings',
#   '318 pages, Hardcover',
#   1,
#   None,
#   '9,583 people are currently reading',
#   '127k people want to read'],
#  ['The Hill We Climb: An Inaugural Poem for the Country',
#   'First published January 1, 2021',
#   'Amanda Gorman',
#   None,
#   '4.55',
#   '33,114 ratings',
#   '29 pages, Hardcover',
#   2,
#   None,
#   '496 people are currently reading',
#   '53k people want to read'],
#  ['A Desolation Called Peace',
#   'First published March 2, 2021',
#   'Arkady Martine',
#   None,
#   '4.32',
#   '31,739 ratings',
#   '496 pages, Kindle Edition',
#   3,
#   None,
#   '2,470 people are currently reading',
#   '31.4k people want to read'],
#  ['A Psalm for the Wild-Built',
#   'First published July 13, 2021',
# ...

# %%
driver = webdriver.Chrome()
scrape_all_pages('https://www.goodreads.com/list/best_of_year/2021?id=157516.Best_Books_of_2021&page=', 14,100)
# Out:
# Scraping page 1
# Scraping book 1
# Scraping book 2
# no ad
# Scraping book 3
# no ad
# Scraping book 4
# no ad
# Scraping book 5
# no ad
# Scraping book 6
# no ad
# Scraping book 7
# no ad
# Scraping book 8
# no ad
# Scraping book 9
# no ad
# Scraping book 10
# no ad
# Scraping book 11
# no ad
# Scraping book 12
# no ad
# Scraping book 13
# no ad
# Scraping book 14
# no ad
# Scraping book 15
# no ad
# Scraping book 16
# no ad
# Scraping book 17
# no ad
# Scraping book 18
# no ad
# Scraping book 19
# no ad
# Scraping book 20
# no ad
# Scraping book 21
# no ad
# Scraping book 22
# no ad
# Scraping book 23
# no ad
# Scraping book 24
# no ad
# Scraping book 25
# no ad
# Scraping book 26
# no ad
# Scraping book 27
# no ad
# Scraping book 28
# no ad
# Scraping book 29
# no ad
# Scraping book 30
# no ad
# Scraping book 31
# no ad
# Scraping book 32
# no ad
# Scraping book 33
# no ad
# Scraping book 34
# no ad
# Scraping book 35
# no ad
# Scraping book 36
# no ad
# Scraping book 37
# no ad
# ...

# %%
driver= webdriver.Chrome()
driver.get('https://www.goodreads.com/list/best_of_year/2021?id=157516.Best_Books_of_2021&page=1')
df = scrape_all_pages()

# %%
df = pd.read_csv('task1.csv')
# Out:
#       Unnamed: 0                                              Title  \
# 0              0                                  Project Hail Mary
# 1              1                                     The Four Winds
# 2              2                                      Malibu Rising
# 3              3                           A Court of Silver Flames
# 4              4                                The Love Hypothesis
# ...          ...                                                ...
# 1358        1358                                      Carnival Hill
# 1359        1359                                        Warrior Fae
# 1360        1360  The Year in Between: A Sense and Sensibility V...
# 1361        1361                      London Bridge is Falling Down
# 1362        1362                        The Princess I Hate to Love
#
#                         Publication Date               Author  \
# 0            First published May 4, 2021            Andy Weir
# ...

# %%
bdf = df.rename(columns = {'Unnamed: 0': 'Index', '0' : 'Title', '1' : 'Date Published', '2':'Author', '3':'Genre', '4':'Average Rating', '5':'Number Ratings', '6': 'Pages', '7':'Rank', '8':'Language', '9':'Currently Reading', '10':'Want Read'})
df = df.drop(columns = ['Index'])

# %%
df.head()
# Out:
#                       Title                    Publication Date  \
# 0         Project Hail Mary         First published May 4, 2021
# 1            The Four Winds    First published February 2, 2021
# 2             Malibu Rising        First published May 27, 2021
# 3  A Court of Silver Flames   First published February 16, 2021
# 4       The Love Hypothesis  First published September 14, 2021
#
#                 Author Genre  Average Rating  Number of Ratings  \
# 0            Andy Weir   NaN            4.50    691,619 ratings
# 1       Kristin Hannah   NaN            4.30    780,238 ratings
# 2  Taylor Jenkins Reid   NaN            4.03  1,138,864 ratings
# 3        Sarah J. Maas   NaN            4.47  1,546,866 ratings
# 4        Ali Hazelwood   NaN            4.13  1,546,517 ratings
#
#                   Pages  Rank  Language                   Currently Reading  \
# 0  476 pages, Hardcover     1       NaN  44.4k people are currently reading
# ...

# %%
# Task 1 Part 3: Genre Ratings
genre_stats = df.groupby('Genre').agg({
    'Average Rating': 'mean',
    'Rank': 'mean'
}).sort_values(by=['Average Rating', 'Rank'], ascending=False)

genre_stats
# Out:
#                    Average Rating   Rank
# Genre
# Biblical Fiction           4.7000  91.00
# Parenting                  4.6100   3.00
# Manga                      4.6100  61.50
# Christian                  4.4825  58.75
# Romantic Suspense          4.4800  76.00
# ...                           ...    ...
# Comics                     3.6100  96.00
# Novella                    3.6000  38.00
# Dystopia                   3.5800  99.00
# LGBT                       3.5650  49.25
# Queer                      3.5400  30.00
#
# [75 rows x 2 columns]

# %%
## Task 1 Part 3: Popularity and ratings 

import matplotlib.pyplot as plt

# Convert number ratings to numeric values
df['Number of Ratings'] = df['Number of Ratings'].str.replace(' ratings', '').str.replace(',', '').astype(int)

# Scatterplot of Number of Ratings vs Average Rating
plt.figure(figsize=(10, 6))
plt.scatter(df['Number of Ratings'], df['Average Rating'], color='blue', alpha=0.6)
plt.title('Relationship Between Number of Ratings and Average Rating')
plt.xlabel('Number of Ratings')
plt.ylabel('Average Rating')
plt.grid(True)
plt.show()

# %%
# Task 2

import pandas as pd
import numpy as np
from selenium import webdriver
import random
import time 

import pandas as pd
import numpy as np
from selenium import webdriver
import random
import time 

def scrape_book2(i):
    """Scrape all info from a singular book."""
    
    try:
        # Click into the book
        rank = i
        
        book_button = driver.find_element('xpath', f'//*[@id="bodycontainer"]/div[3]/div[1]/div[1]/div[2]/table/tbody/tr[{i}]/td[2]/a/span')
        book_button.click()
       
        # Check for pop-up ad
        time.sleep(random.uniform(1.9, 2.4))
        try:
            ad_button = driver.find_element('xpath', '/html/body/div[3]/div/div[1]/div/div/button')
            ad_button.click()
            time.sleep(random.uniform(1.9, 2.4))
    
        except:
            print('no ad') 
       
        # Scrape info
        book_info = []
        title = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[1]/div[1]/h1').text
        
        try:
            try:
                pub_date = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/div/span[1]/span/div/p[2]').text
            except:
                pub_date = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/div/span[1]/span/div/p').text
            
        except: 
            pub_date = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[5]/div/span[1]/span/div/p[2]').text
       
        author = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[1]/h3/div/span[1]/a/span[1]').text
        avg_rating = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[2]/a/div[1]/div').text
        num_ratings = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[2]/a/div[2]/div/span[1]').text
        try:
            pages = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/div/span[1]/span/div/p[1]').text
        except:
            pages = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[5]/div/span[1]/span/div/p[1]').text
    
        # Optional fields
        try:
            genre = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[5]/ul/span[1]/span[2]/a/span').text
        except:
            genre = None
    
        try:
            num_reading = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/div[1]/span/div[2]/div').text
        except:
            num_reading = None
            
        try:
            num_want_read = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/div[2]/span/div[2]/div').text
        except: 
            num_want_read = None
            
    
        # scroll down to book details & editions and click
        try: 
            details_button = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/div/div/button/span[1]')
            driver.execute_script("arguments[0].scrollIntoView(true);", details_button)
            time.sleep(random.uniform(1.9, 2.4))
            details_button.click()
        except:
            details_button = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[5]/div/div/button/span[1]')
            driver.execute_script("arguments[0].scrollIntoView(true);", details_button)
            time.sleep(random.uniform(1.9, 2.4))
            details_button.click()
          
        # Language (if available)
        try:
            try:
                language = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/div/span[2]/div[1]/span/div/dl/div[5]/dd/div/div[1]').text
            except:
                language = driver.find_element('xpath', '//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[5]/div/span[2]/div[1]/span/div/dl/div[5]/dd/div/div[1]').text
        except:
            language = None
    
    
        # Back to book list page
        time.sleep(random.uniform(0.7,1.2))
        driver.back()
        
        if pub_date:  # return book info
            book_info.append([title, pub_date, author, genre, avg_rating, num_ratings, pages, rank, language, num_reading, num_want_read])
        return book_info
    
    except:
        driver.back()  # Ensure the browser navigates back even if an error occurs
        return None  # Return None or an empty list to indicate failure
    


def scrape_page2(books_per_page):
    """Scrape a page of books."""
    books = []
    for i in range(1, books_per_page + 1):
        print(f"Scraping book {i}")
        book = scrape_book2(i)
        if book:  # Only add to the list if the book scrape was successful
            books.extend(book)
        else:
            print(f"Book {i} failed")
    return books

def scrape_all_pages2(url, pages, books_per_page):
    """Scrape all pages of books."""
    books = []
    for i in range(1, pages + 1):
        page_url = f"{url}{i}"
        driver.get(page_url)
        print(f'Scraping page {i}')
        books.extend(scrape_page2(books_per_page))
        time.sleep(random.uniform(1.9, 2.4))

    # Save to CSV
    books_df = pd.DataFrame(books, columns=['Title', 'Publication Date', 'Author', 'Genre', 'Average Rating', 'Number of Ratings', 
                                            'Pages', 'Rank','Language', 'Currently Reading', 'Want to Read'])
    books_df.to_csv('hemingway.csv')
    return books_df

# %%
# new xpaths

f'//*[@id="bodycontainer"]/div[3]/div[1]/div[1]/div[2]/table/tbody/tr[{i}]/td[2]/a/span' # click into book
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[1]/div[1]/h1 # title 
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[2]/a/div[1]/div # avg rating
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[2]/a/div[2]/div/span[1]/text()[1] # num ratings
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/div/span[1]/span/div/p[1] # pages
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/div/div/button/span[1] # details_button
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/div[1]/span/div[2]/div # num_reading
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[7]/div/div[2]/span/div[2]/div # num_want_read
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/div/span[2]/div[1]/span/div/dl/div[5]/dd/div/div[1] # language
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[6]/div/span[1]/span/div/p[2] # pub_date
//*[@id="__next"]/div[2]/main/div[1]/div[2]/div[2]/div[2]/div[5]/ul/span[1]/span[2]/a/span # genre

# %%
driver = webdriver.Chrome()
scrape_all_pages2('https://www.goodreads.com/author/list/1455.Ernest_Hemingway?page=',60,30)

# %%
driver = webdriver.Chrome()
driver.get('https://www.goodreads.com/author/list/1455.Ernest_Hemingway?page=1')
scrape_book2(4)
# Out:
# [['For Whom the Bell Tolls',
#   'First published October 1, 1940',
#   'Ernest Hemingway',
#   'Classics',
#   '3.98',
#   '302,756 ratings',
#   '471 pages, Paperback',
#   4,
#   None,
#   '14.1k people are currently reading',
#   '314k people want to read']]

# %%
driver = webdriver.Chrome()
driver.get('https://www.goodreads.com/author/list/1455.Ernest_Hemingway?page=3&per_page=3')
pd.DataFrame(scrape_page2(4))
# Out:
# Scraping book 1
# Scraping book 2
# no ad
# Scraping book 3
# no ad
# Scraping book 4
# Book 4 failed
#                                                0   \
# 0  The Complete Short Stories of Ernest Hemingway
# 1                            To Have and Have Not
# 2                                     In Our Time
#
#                                 1                 2              3     4   \
# 0  First published January 1, 1987  Ernest Hemingway  Short Stories  4.29
# 1  First published January 1, 1937  Ernest Hemingway        Fiction  3.52
# 2  First published January 1, 1924  Ernest Hemingway       Classics  3.74
#
#                5                     6   7        8   \
# 0  37,056 ratings  650 pages, Paperback   1  English
# 1  34,107 ratings  176 pages, Hardcover   2     None
# 2  25,803 ratings  156 pages, Paperback   3     None
#
#                                    9                          10
# 0  5,400 people are currently reading  47.2k people want to read
# ...

# %%
df2 = pd.read_csv('hemingway.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0                    Title                   Publication Date  \
# 0           0  The Old Man and the Sea  First published September 1, 1952
# 1           1       The Sun Also Rises   First published October 22, 1926
# 2           2       A Farewell to Arms  First published September 1, 1929
# 3           3  For Whom the Bell Tolls    First published October 1, 1940
# 4           4         A Moveable Feast    First published January 1, 1964
#
#              Author       Genre  Average Rating  Number of Ratings  \
# 0  Ernest Hemingway     Fiction            3.81  1,212,427 ratings
# 1  Ernest Hemingway    Classics            3.79    462,777 ratings
# 2  Ernest Hemingway     Fiction            3.82    333,348 ratings
# 3  Ernest Hemingway    Classics            3.98    302,756 ratings
# 4  Ernest Hemingway  Nonfiction            4.02    157,330 ratings
#
#                   Pages  Rank Language                   Currently Reading  \
# ...

# %%
df2['Number of Ratings'].value_counts()
# Out:
# Number of Ratings
# 0      745
# 1      140
# 2       68
# 3       43
# 4       37
#       ...
# 140      1
# 167      1
# 149      1
# 193      1
# 46       1
# Name: count, Length: 196, dtype: int64

# %%
def convert_abbrev_num(num_str):
    # Remove commas for clean conversion
    num_str = num_str.replace(',', '')
    
    # Check if the last character is a digit and directly convert to integer if true
    if num_str[-1].isdigit():
        return int(num_str)
    
    # Extract the numeric part and the suffix
    number = num_str[:-1]
    suffix = num_str[-1].lower()
    
    # Determine the multiplier based on the suffix
    multiplier = 1  # Default is no multiplication
    if suffix == 'k':
        multiplier = 1000
    elif suffix == 'm':
        multiplier = 1000000
    elif suffix == 'b':
        multiplier = 1000000000
    else:
        raise ValueError(f"Unsupported suffix '{suffix}' in input.")
    
    # Return the numeric part multiplied by the determined multiplier
    return int(float(number) * multiplier)

# %%
# # # df2 data cleaning

df2 = df2.drop(columns = ['Unnamed: 0'])
df2['Publication Date'] = df2['Publication Date'].str.replace('First published ', '', regex=True)
df2['Publication Date'] = pd.to_datetime(df2['Publication Date'], errors='coerce', format='%B %d, %Y')

df2['Number of Ratings'] = df2['Number of Ratings'].str.replace(' ratings', '').str.replace(',','').fillna(0)

# First, ensure the column is of type string
df2['Pages'] = df2['Pages'].astype(str)

# # Use the str.replace() method to remove both types of substrings without a loop
df2['Pages'] = df2['Pages'].str.replace(' pages, Hardcover', '').str.replace(' pages, Paperback', '')
df2['Pages'] = pd.to_numeric(df2['Pages'], errors='coerce')



# # Remove 'k' and periods, convert 'k' to '000', and remove commas
df2['Currently Reading'] = df2['Currently Reading'].str.replace('k', '000').str.replace('b','000000').str.replace('.', '').str.replace(',', '').str.replace(' people are currently reading','').str.replace(' person is currently reading','').fillna(0).str.replace(' people want to read', '')
df2['Want to Read'] = df2['Want to Read'].str.replace('k', '000').str.replace('b','000000').str.replace('.', '').str.replace(',', '').fillna(0).str.replace(' people want to read', '')

# # # Convert to integer
df2['Number of Ratings'] = df2['Number of Ratings'].str.replace(',', '').str.replace(' rating', '').astype(int)
df2['Average Rating'] = df2['Average Rating'].astype(float)

# %%
# Task 2 Analysis: Language

language_distribution = df['Language'].value_counts().reset_index()
language_distribution.columns = ['Language', 'Count of Books']
language_distribution
# Out:
#   Language  Count of Books
# 0  English             127

# %%
# Author Age and Page count

from datetime import datetime

# Hemingway's birthday
hemingway_birthday = datetime(1899, 7, 21)

# Calculate age at each publication
df2['Author Age'] = (df2['Publication Date'] - hemingway_birthday).dt.days // 365


plt.figure(figsize=(10, 6))
plt.plot(df2['Author Age'], df2['Pages'], marker='o', linestyle='-', color='blue')
plt.title('Author Age vs. Page Count')
plt.xlabel('Author Age at Publication')
plt.ylabel('Page Count')
plt.grid(True)
plt.show()

# %% [markdown]
# Slight upward correlation between age at publication and page count. Maybe in his older age, Hemingway tended to write run-on sentences and was long-winded.

# %%
# Age vs. Average Rating

# Filter English-only books
english_books = df2[df2['Language'] == 'English']

# Plotting English-only books
plt.figure(figsize=(10, 6))
plt.plot(english_books['Author Age'], english_books['Average Rating'], marker='o', linestyle='-', color='blue')
plt.title('Author Age vs. Average Rating (English Books)')
plt.xlabel('Author Age at Publication')
plt.ylabel('Average Rating')
plt.grid(True)
plt.show()

# %% [markdown]
# Slight postitive trend between Hemingway's age at the time of publication and the average rating. Could be an indicator that he got better at writing with age. Or possibly he was just a bigger name and people gave his books high ratings because of his reputation.

# %%
# Age vs. Average Rating: Plotting all books
plt.figure(figsize=(10, 6))
plt.plot(df2['Author Age'], df2['Average Rating'], marker='o', linestyle='-', color='red')
plt.title('Author Age vs. Average Rating (All Languages)')
plt.xlabel('Author Age at Publication')
plt.ylabel('Average Rating')
plt.grid(True)
plt.show()

# %% [markdown]
# Slight postitive trend between Hemingway's age at the time of publication and the average rating. Could be an indicator that he got better at writing with age. Or possibly he was just a bigger name and people gave his books high ratings because of his reputation.

# %%
# Pages vs. Ratings

plt.figure(figsize=(10, 6))
plt.scatter(df2['Pages'], df2['Average Rating'], color='blue')
plt.title('Pages vs. Average Rating')
plt.xlabel('Page Count')
plt.ylabel('Average Rating')
plt.grid(True)
plt.show()

# %% [markdown]
# Not a clear trend between page count and average rating, most of Hemingway's books are sitting round 3.5-4, with a couple exceptions. So the number of pages doesn't seem to be a true indicator.

# %%
df2.dtypes
# Out:
# Title                        object
# Publication Date     datetime64[ns]
# Author                       object
# Genre                        object
# Average Rating              float64
# Number of Ratings             int64
# Pages                       float64
# Rank                          int64
# Language                     object
# Currently Reading            object
# Want to Read                 object
# Author Age                  float64
# dtype: object

# %%
print(df2['Number of Ratings'].max())
print(df2['Number of Ratings'].min())
1290696/50
# Out:
# 1290696
# 0
# 25813.92

# %%
# Interest on a book

import matplotlib.ticker as ticker

plt.figure(figsize=(12, 8))
plt.scatter(df2['Currently Reading'].astype(str), df2['Number of Ratings'].astype(str), color='blue', s=100, label='Book Ratings')
plt.title('Interest vs. Number of Ratings', fontsize=16)
plt.xticks(rotation = 90, fontsize = 8)
plt.gca().get_yaxis().set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.yticks(fontsize=12)
plt.xlabel('Number of People Currently Reading', fontsize=14)
plt.ylabel('Number of Ratings', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Definitely a visible trend between the number of people currently reading the book and the number of ratings, which makes intuitive sense because for people to rate the book, they probably need to read the book prior.
